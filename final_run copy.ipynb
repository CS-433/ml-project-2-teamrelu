# %%
import torch
import torch.nn as nn
import json
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import train_test_split
from configs.dataloaders import create_data_loaders
from runner_static import static_training
from runner_dynamic import dynamic_training
from models.static_models.static_model_multibranch import StaticModelMultibranch
from models.dynamic_models.lstm_model import LSTMDynamicModel
from trainers.cross_validation import k_fold_cross_validation_static, k_fold_cross_validation_dynamic
from losses.losses import CrossEntropy, CrossEntropyWithLasso, CrossEntropyWithTemporalSmoothness

# %% [markdown]
# # Static Model

# %% [markdown]
# The main goal of this first part is to try different architectures and select the one that performs better for the **static protein localization problem**.
#
# We start by initializing all the indispensable variables and loading hyperparameters from `hyperparameters.json`. From now on, all the  __bold_variables__ are to be considered as taken from this JSON file.

# %%
# Initialize random seed
seed = 30026
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)

# Define dimensions of the problem
num_classes = 15
num_timesteps = 5
num_features = 34 # both static and dynamic

# Decide whever to be verbose with display outputs and set device
verbose = True
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Define hyperparameters
with open('hyperparameters.json', 'r') as file:
    params = json.load(file)

static_params = params["static_model"]

# Load file
data = pd.read_csv(params["file_path"])

# %% [markdown]
# Since our models will be combined together for creating more complex models, we split data in train and validation sets once and for all before creating all models: in this way, we avoid the risk of using the same samples for train and for validate at the same time.

# %%
# Split dataset in train and test sets keeping balance for the static label localization
data_train, data_test = train_test_split(data, test_size=params["test_size"], random_state=seed, stratify = data['static_localization'])

# Create dataloaders
dataloader_train, dataloader_test = create_data_loaders(data_train, data_test, params["batch_size"])

# %% [markdown]
# ## First Model: Multi-Layer-Perceptron

# %% [markdown]
# Our first try is a simple MLP with just a hidden layer of size __intermediate_dim__, which takes as input the ESM-embeddings (you can choose between small and big embeddings with __long_embeddings__ boolean variable, depending on computational availabilities).
#
# We are using techniques for regularization which will be present in all our architectures: dropout, weight_decay, early stopping, layer normalization, weight initialization, learning rate scheduler.
#
# In this first phase, we only try some reasonable hyperparameters choices: because of high compuational costs, we cannot do cross-validation on all the hyperparameters for all the models, but we will do it for our best static model.

# %%
# Running the first model
train_loss, train_accuracy, test_loss, test_accuracy, static_model_dict = static_training(num_classes, static_params, dataloader_train, dataloader_test, verbose, device)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Running the first model
# ----> 2 train_loss, train_accuracy, test_loss, test_accuracy, static_model_dict = static_training(num_classes, static_params, dataloader_train, dataloader_test, verbose, device)
#
# File ~/epfl/ml-project-2-teamrelu/runner_static.py:18, in static_training(num_classes, static_params, dataloader_train, dataloader_test, verbose, device)
#      15 def static_training(num_classes, static_params, dataloader_train, dataloader_test, verbose, device):
#      16
#      17     # Set embedding dimensions based on json parameter
# ---> 18     if static_params["long_embeddings"]:
#      19         embedding_dim = 640
#      20     else:
#
# KeyError: 'long_embeddings'

# %% [markdown]
# Even though we have used some technique like __dropout__, __weight_decay__ and early stopping (set with __patience__ parameter), this model appears to strongly overfit.

# %% [markdown]
# ## Second Model: XGBoost

# %% [markdown]
# Commento di Riki aaaaaa
#
# Since XGBoost has a different architecture, we will use an appositely create JSON file `hyperparametersxgb.json`.

# %%
# Define hyperparameters
with open('hyperparametersxgb.json', 'r') as file:
    xgb_params = json.load(file)

xgb_params = xgb_params["static_model"]

# %%
# Running the second model
train_loss, train_accuracy, test_loss, test_accuracy, static_model_dict = static_training(num_classes, xgb_params, dataloader_train, dataloader_test, verbose, device)
# Out:
# Starting training of XGBoost
# [0]	train-mlogloss:2.70180	train-merror:0.37500	test-mlogloss:2.70669	test-merror:0.81250
# [25]	train-mlogloss:2.55404	train-merror:0.34375	test-mlogloss:2.66291	test-merror:0.75000
# [50]	train-mlogloss:2.42204	train-merror:0.34375	test-mlogloss:2.61855	test-merror:0.75000
# [75]	train-mlogloss:2.30472	train-merror:0.34375	test-mlogloss:2.58300	test-merror:0.75000
# [100]	train-mlogloss:2.19836	train-merror:0.37500	test-mlogloss:2.55792	test-merror:0.71875
# [125]	train-mlogloss:2.10559	train-merror:0.37500	test-mlogloss:2.53734	test-merror:0.71875
# [150]	train-mlogloss:2.02557	train-merror:0.37500	test-mlogloss:2.51902	test-merror:0.68750
# [175]	train-mlogloss:1.95740	train-merror:0.37500	test-mlogloss:2.50267	test-merror:0.68750
# [200]	train-mlogloss:1.91222	train-merror:0.37500	test-mlogloss:2.48511	test-merror:0.68750
# [225]	train-mlogloss:1.87771	train-merror:0.37500	test-mlogloss:2.46554	test-merror:0.68750
# [250]	train-mlogloss:1.84771	train-merror:0.37500	test-mlogloss:2.44755	test-merror:0.68750
# [275]	train-mlogloss:1.82149	train-merror:0.37500	test-mlogloss:2.43197	test-merror:0.68750
# [300]	train-mlogloss:1.80726	train-merror:0.40625	test-mlogloss:2.41427	test-merror:0.71875
# [325]	train-mlogloss:1.79629	train-merror:0.40625	test-mlogloss:2.39782	test-merror:0.71875
# [350]	train-mlogloss:1.78658	train-merror:0.40625	test-mlogloss:2.38287	test-merror:0.71875
# [375]	train-mlogloss:1.77794	train-merror:0.40625	test-mlogloss:2.36924	test-merror:0.71875
# [400]	train-mlogloss:1.77022	train-merror:0.40625	test-mlogloss:2.35677	test-merror:0.71875
# [425]	train-mlogloss:1.76331	train-merror:0.40625	test-mlogloss:2.34535	test-merror:0.71875
# [450]	train-mlogloss:1.75710	train-merror:0.40625	test-mlogloss:2.33486	test-merror:0.75000
# [475]	train-mlogloss:1.75149	train-merror:0.40625	test-mlogloss:2.32520	test-merror:0.75000
# [500]	train-mlogloss:1.74642	train-merror:0.40625	test-mlogloss:2.31630	test-merror:0.75000
# [525]	train-mlogloss:1.74183	train-merror:0.40625	test-mlogloss:2.30808	test-merror:0.75000
# [550]	train-mlogloss:1.73766	train-merror:0.40625	test-mlogloss:2.30048	test-merror:0.75000
# [575]	train-mlogloss:1.73386	train-merror:0.40625	test-mlogloss:2.29344	test-merror:0.75000
# [600]	train-mlogloss:1.73040	train-merror:0.40625	test-mlogloss:2.28693	test-merror:0.75000
# [625]	train-mlogloss:1.72724	train-merror:0.40625	test-mlogloss:2.28089	test-merror:0.75000
# [650]	train-mlogloss:1.72435	train-merror:0.40625	test-mlogloss:2.27529	test-merror:0.75000
# [675]	train-mlogloss:1.72170	train-merror:0.40625	test-mlogloss:2.27009	test-merror:0.75000
# [700]	train-mlogloss:1.71927	train-merror:0.40625	test-mlogloss:2.26526	test-merror:0.75000
# [725]	train-mlogloss:1.71704	train-merror:0.40625	test-mlogloss:2.26077	test-merror:0.75000
# [750]	train-mlogloss:1.71499	train-merror:0.40625	test-mlogloss:2.25660	test-merror:0.75000
# [775]	train-mlogloss:1.71311	train-merror:0.40625	test-mlogloss:2.25272	test-merror:0.75000
# [800]	train-mlogloss:1.71137	train-merror:0.40625	test-mlogloss:2.24911	test-merror:0.75000
# [825]	train-mlogloss:1.70977	train-merror:0.40625	test-mlogloss:2.24576	test-merror:0.75000
# [850]	train-mlogloss:1.70830	train-merror:0.40625	test-mlogloss:2.24263	test-merror:0.75000
# [875]	train-mlogloss:1.70694	train-merror:0.40625	test-mlogloss:2.23973	test-merror:0.75000
# [900]	train-mlogloss:1.70568	train-merror:0.40625	test-mlogloss:2.23702	test-merror:0.75000
# [925]	train-mlogloss:1.70452	train-merror:0.40625	test-mlogloss:2.23450	test-merror:0.75000
# [950]	train-mlogloss:1.70345	train-merror:0.40625	test-mlogloss:2.23215	test-merror:0.75000
# [975]	train-mlogloss:1.70246	train-merror:0.40625	test-mlogloss:2.22997	test-merror:0.75000
# [999]	train-mlogloss:1.70158	train-merror:0.40625	test-mlogloss:2.22801	test-merror:0.75000

# %% [markdown]
# ## Third Model: StaticModelMultibranch

# %% [markdown]
# The last static models is created with more complex architecture: since from biological analysis we expect the first and last amino acids of each sequence to be the most representative for our task, this neural networks takes as input also the strings of first and last 20 amino acids of each sequence. These strings are embedded by some transformer layers and then given to some MLP layer together with ESM-embeddings.

# %% [markdown]
# ### Training

# %%
# Change model_type for running the right model (from 0 to 2, for more info look at static_training inside runner_static.py)
static_params["model_type"] +=2

# %%
# Running the third model
train_loss, train_accuracy, test_loss, test_accuracy, static_model_dict = static_training(num_classes, static_params, dataloader_train, dataloader_test, verbose, device)
# Out:
# Starting training of StaticModelMultibranch
# Epoch [1/100],	Training Loss: 2.5538, Training accuracy: 29.03,	Test Loss: 1.8178, Test Accuracy: 34.27,	Learning rate: 0.01000
# Epoch [2/100],	Training Loss: 1.8385, Training accuracy: 32.98,	Test Loss: 1.7229, Test Accuracy: 35.68,	Learning rate: 0.01000
# Epoch [3/100],	Training Loss: 1.6839, Training accuracy: 39.82,	Test Loss: 1.5292, Test Accuracy: 46.97,	Learning rate: 0.01000
# Epoch [4/100],	Training Loss: 1.5773, Training accuracy: 46.42,	Test Loss: 1.5051, Test Accuracy: 49.65,	Learning rate: 0.01000
# Epoch [5/100],	Training Loss: 1.4923, Training accuracy: 48.04,	Test Loss: 1.4983, Test Accuracy: 46.69,	Learning rate: 0.01000
# Epoch [27/100],	Training Loss: 0.7998, Training accuracy: 71.39,	Test Loss: 1.4639, Test Accuracy: 58.67,	Learning rate: 0.00100
# Epoch [28/100],	Training Loss: 0.8000, Training accuracy: 71.29,	Test Loss: 1.4749, Test Accuracy: 56.98,	Learning rate: 0.00100
# Epoch [29/100],	Training Loss: 0.7971, Training accuracy: 70.97,	Test Loss: 1.4583, Test Accuracy: 58.11,	Learning rate: 0.00100
# Epoch [30/100],	Training Loss: 0.7862, Training accuracy: 71.57,	Test Loss: 1.5206, Test Accuracy: 57.55,	Learning rate: 0.00100
# Epoch [31/100],	Training Loss: 0.7655, Training accuracy: 72.13,	Test Loss: 1.5107, Test Accuracy: 59.10,	Learning rate: 0.00100
# Early stopping triggered after 31 epochs. Best test loss: 1.3435

# %% [markdown]
# By analyzing our main metrics (validation loss and validation accuracy) and the behavior in terms of overfitting, we can conclude that this is the best static model we have created.
# For this reason, we perform k-fold cross-validation for finding the best hyperparameters of our model.

# %% [markdown]
# ### K-Fold Cross validation

# %%
# Choose parameters for grid cross-validation
parameter_grid = {
    "dropout": [0, 0.25, 0.5],
    "learning_rate": [0.001, 0.01],
    "weight_decay": [0, 0.0001, 0.01],
    "scheduler": ['CosineAnnealingLR', 'StepLR', 'ExponentialLR']
}
# Setting principal fixed parameters
k_folds = 3
num_epochs = 100
patience = 20
batch_size = 32

best_params, results = k_fold_cross_validation_static(
    StaticModelMultibranch,
    data,
    CrossEntropy,
    parameter_grid,
    num_epochs,
    patience,
    batch_size,
    device,
    k_folds=k_folds,
    seed=seed,
    cross_validation_on_loss=True,
    verbose=True
)

# %%
# We save best results in a json file for using them in a second moment
results_file = 'cross_val_results'
with open(results_file, 'w') as f:
    json.dump(results, f, indent=4)

best_file = 'best_results'
with open(best_file, 'w') as f:
    json.dump(best_params, f, indent=4)

# %% [markdown]
# Starting from this parameters, we create a new `hyperparameters_cross_validation.json` file for running our best model on the hyperparameters obtained with 3-fold cross-validation. The result of this training will be our best static architecture and will be used in the second part of the project.

# %%
# Load hyperparameters
with open('hyperparameters_cross_val.json', 'r') as file:
    params = json.load(file)

static_params = params["static_model"]
dynamic_params = params["dynamic_model"]

# Set embedding dimensions based on json parameter
if static_params["long_embeddings"]:
    embedding_dim = 640
else:
    embedding_dim = 320

# %%
# Running the third model
train_loss, train_accuracy, test_loss, test_accuracy, static_model_dict = static_training(num_classes, static_params, dataloader_train, dataloader_test, verbose, device)
# Out:
# Starting training of StaticModelMultibranch
# Epoch [1/100],	Training Loss: 2.3817, Training accuracy: 28.96,	Test Loss: 1.8273, Test Accuracy: 37.80,	Learning rate: 0.00100
# Epoch [2/100],	Training Loss: 1.8299, Training accuracy: 37.85,	Test Loss: 1.6242, Test Accuracy: 43.58,	Learning rate: 0.00100
# Epoch [3/100],	Training Loss: 1.6489, Training accuracy: 43.53,	Test Loss: 1.4827, Test Accuracy: 47.81,	Learning rate: 0.00100
# Epoch [24/100],	Training Loss: 0.7905, Training accuracy: 70.79,	Test Loss: 1.3384, Test Accuracy: 58.39,	Learning rate: 0.00010
# Epoch [25/100],	Training Loss: 0.7559, Training accuracy: 72.95,	Test Loss: 1.3678, Test Accuracy: 59.80,	Learning rate: 0.00010
# Epoch [26/100],	Training Loss: 0.7733, Training accuracy: 71.60,	Test Loss: 1.3569, Test Accuracy: 59.24,	Learning rate: 0.00010
# Epoch [27/100],	Training Loss: 0.7721, Training accuracy: 71.89,	Test Loss: 1.3618, Test Accuracy: 58.82,	Learning rate: 0.00010
# Epoch [28/100],	Training Loss: 0.7487, Training accuracy: 73.05,	Test Loss: 1.3753, Test Accuracy: 60.37,	Learning rate: 0.00010
# Epoch [29/100],	Training Loss: 0.7403, Training accuracy: 73.23,	Test Loss: 1.3622, Test Accuracy: 59.10,	Learning rate: 0.00010
# Epoch [30/100],	Training Loss: 0.7536, Training accuracy: 71.78,	Test Loss: 1.3828, Test Accuracy: 58.11,	Learning rate: 0.00010
# Epoch [31/100],	Training Loss: 0.7468, Training accuracy: 73.37,	Test Loss: 1.3768, Test Accuracy: 59.10,	Learning rate: 0.00010
# Epoch [32/100],	Training Loss: 0.7352, Training accuracy: 73.16,	Test Loss: 1.3908, Test Accuracy: 59.38,	Learning rate: 0.00010
# Epoch [33/100],	Training Loss: 0.7349, Training accuracy: 73.40,	Test Loss: 1.3841, Test Accuracy: 59.38,	Learning rate: 0.00010
# Epoch [34/100],	Training Loss: 0.7084, Training accuracy: 74.53,	Test Loss: 1.3843, Test Accuracy: 59.24,	Learning rate: 0.00010
# Early stopping triggered after 34 epochs. Best test loss: 1.2989

# %%
# Save best model
static_model = StaticModelMultibranch(num_classes=num_classes, embedding_dim=embedding_dim, extremities_dim=20, char_vocab_size=20, char_embed_dim=16, intermediate_dim=static_params["intermediate_dim"], dropout=static_params["dropout"])

# Load the weights from the dictionary
static_model.load_state_dict(static_model_dict)
# Out:
# <All keys matched successfully>

# %% [markdown]
# # Dynamic Model

# %% [markdown]
# In this second part, we try to solve the dynamic counterpart of the localization problem: every protein can now change position during eukaryotic cell cycle, which consists of 5 different timesteps.

# %% [markdown]
# ## First Model: ModulableLSTMDynamicModel

# %% [markdown]
# The first model consists of a LSTM architecture which takes as input the dynamic data and the output of the StaticModelMultibranch static model. The model can be trained on the whole dataset or only on part of it (in particular it can decide wheter to take __protein interactions matrix__, __protein concentration levels__ and __static_data__, with all the possible combinations available).

# %%
# Load hyperparameters
dynamic_params = params["dynamic_model"]

# %%
# Run training
train_loss, train_accuracy, test_loss, test_accuracy, lstm_dynamic_model = dynamic_training(num_features, num_classes, num_timesteps, embedding_dim, dynamic_params, static_model, dataloader_train, dataloader_test, verbose, device)
# Out:
# Starting training of ModulableLSTMDynamicModel
# Epoch [1/100],	Training Loss: 1.7143, Training accuracy: 43.07,	Test Loss: 1.5000, Test Accuracy: 51.82,	Learning rate: 0.00100
# Epoch [23/100],	Training Loss: 0.7923, Training accuracy: 75.01,	Test Loss: 1.3516, Test Accuracy: 58.98,	Learning rate: 0.00010
# Epoch [24/100],	Training Loss: 0.8409, Training accuracy: 72.40,	Test Loss: 1.3445, Test Accuracy: 58.28,	Learning rate: 0.00010
# Epoch [25/100],	Training Loss: 0.7869, Training accuracy: 74.44,	Test Loss: 1.3453, Test Accuracy: 58.14,	Learning rate: 0.00010
# Epoch [26/100],	Training Loss: 0.7907, Training accuracy: 74.22,	Test Loss: 1.3470, Test Accuracy: 58.62,	Learning rate: 0.00010
# Epoch [27/100],	Training Loss: 0.8108, Training accuracy: 73.86,	Test Loss: 1.3437, Test Accuracy: 58.56,	Learning rate: 0.00010
# Epoch [28/100],	Training Loss: 0.7802, Training accuracy: 75.56,	Test Loss: 1.3457, Test Accuracy: 58.56,	Learning rate: 0.00010
# Epoch [29/100],	Training Loss: 0.7801, Training accuracy: 74.92,	Test Loss: 1.3520, Test Accuracy: 58.56,	Learning rate: 0.00010
# Epoch [30/100],	Training Loss: 0.8196, Training accuracy: 73.54,	Test Loss: 1.3442, Test Accuracy: 57.88,	Learning rate: 0.00010
# Epoch [31/100],	Training Loss: 0.7775, Training accuracy: 74.91,	Test Loss: 1.3477, Test Accuracy: 58.73,	Learning rate: 0.00010
# Epoch [32/100],	Training Loss: 0.7914, Training accuracy: 75.00,	Test Loss: 1.3426, Test Accuracy: 58.45,	Learning rate: 0.00010
# Epoch [33/100],	Training Loss: 0.7999, Training accuracy: 74.22,	Test Loss: 1.3453, Test Accuracy: 58.56,	Learning rate: 0.00010
# Epoch [34/100],	Training Loss: 0.7855, Training accuracy: 74.72,	Test Loss: 1.3531, Test Accuracy: 58.42,	Learning rate: 0.00010
# Epoch [35/100],	Training Loss: 0.7853, Training accuracy: 74.78,	Test Loss: 1.3565, Test Accuracy: 58.17,	Learning rate: 0.00010
# Epoch [36/100],	Training Loss: 0.8039, Training accuracy: 73.74,	Test Loss: 1.3508, Test Accuracy: 58.65,	Learning rate: 0.00010
# Early stopping triggered after 36 epochs. Best test loss: 1.3244

# %% [markdown]
# ## Second Model: TCNModel

# %%
# Change model_type for running the right model (from 0 to 1, for more info look at dynamic_training inside runner_dynamic.py)
dynamic_params["model_type"] +=1

# %%
# Run training
train_loss, train_accuracy, test_loss, test_accuracy, dynamic_model = dynamic_training(num_features, num_classes, num_timesteps, embedding_dim, dynamic_params, static_model, dataloader_train, dataloader_test, verbose, device)
# Out:
# Starting training of TCNDynamicModel
# Epoch [1/100],	Training Loss: 2.1067, Training accuracy: 33.42,	Test Loss: 1.6825, Test Accuracy: 44.46,	Learning rate: 0.00100
# Epoch [2/100],	Training Loss: 1.4769, Training accuracy: 50.61,	Test Loss: 1.4718, Test Accuracy: 52.69,	Learning rate: 0.00100
# Epoch [3/100],	Training Loss: 1.2673, Training accuracy: 58.09,	Test Loss: 1.3857, Test Accuracy: 55.29,	Learning rate: 0.00100
# Epoch [24/100],	Training Loss: 0.7935, Training accuracy: 73.30,	Test Loss: 1.2843, Test Accuracy: 58.79,	Learning rate: 0.00010
# Epoch [25/100],	Training Loss: 0.7756, Training accuracy: 73.59,	Test Loss: 1.2855, Test Accuracy: 58.76,	Learning rate: 0.00010
# Epoch [26/100],	Training Loss: 0.7877, Training accuracy: 73.45,	Test Loss: 1.2840, Test Accuracy: 58.70,	Learning rate: 0.00010
# Epoch [27/100],	Training Loss: 0.7816, Training accuracy: 73.71,	Test Loss: 1.2854, Test Accuracy: 58.73,	Learning rate: 0.00010
# Epoch [28/100],	Training Loss: 0.7816, Training accuracy: 73.73,	Test Loss: 1.2847, Test Accuracy: 58.65,	Learning rate: 0.00010
# Epoch [29/100],	Training Loss: 0.7824, Training accuracy: 74.28,	Test Loss: 1.2837, Test Accuracy: 58.76,	Learning rate: 0.00010
# Epoch [30/100],	Training Loss: 0.7932, Training accuracy: 73.10,	Test Loss: 1.2852, Test Accuracy: 58.73,	Learning rate: 0.00010
# Epoch [31/100],	Training Loss: 0.7788, Training accuracy: 73.86,	Test Loss: 1.2876, Test Accuracy: 58.93,	Learning rate: 0.00010
# Early stopping triggered after 31 epochs. Best test loss: 1.2689

# %% [markdown]
# ## Third Model: SimpleModel

# %%
# Change model_type for running the right model (from 1 to 2, for more info look at dynamic_training inside runner_dynamic.py)
dynamic_params["model_type"] +=1

# %%
# Run training
train_loss, train_accuracy, test_loss, test_accuracy, model = dynamic_training(num_features, num_classes, num_timesteps, embedding_dim, dynamic_params, static_model, dataloader_train, dataloader_test, verbose, device)
# Out:
# Starting training of SimpleDynamicModel
# Epoch [1/100],	Training Loss: 2.0385, Training accuracy: 34.50,	Test Loss: 1.8272, Test Accuracy: 36.67,	Learning rate: 0.00100
# Epoch [2/100],	Training Loss: 1.7569, Training accuracy: 39.24,	Test Loss: 1.7141, Test Accuracy: 41.10,	Learning rate: 0.00100
# Epoch [3/100],	Training Loss: 1.6568, Training accuracy: 43.05,	Test Loss: 1.6443, Test Accuracy: 42.65,	Learning rate: 0.00100
# Epoch [4/100],	Training Loss: 1.5893, Training accuracy: 46.46,	Test Loss: 1.5928, Test Accuracy: 45.08,	Learning rate: 0.00100
# Epoch [5/100],	Training Loss: 1.5325, Training accuracy: 49.19,	Test Loss: 1.5539, Test Accuracy: 47.17,	Learning rate: 0.00100
# Epoch [6/100],	Training Loss: 1.4909, Training accuracy: 50.66,	Test Loss: 1.5224, Test Accuracy: 47.53,	Learning rate: 0.00100
# Epoch [7/100],	Training Loss: 1.4563, Training accuracy: 52.06,	Test Loss: 1.4979, Test Accuracy: 48.97,	Learning rate: 0.00100
# Epoch [8/100],	Training Loss: 1.4288, Training accuracy: 53.17,	Test Loss: 1.4810, Test Accuracy: 48.60,	Learning rate: 0.00100
# Epoch [9/100],	Training Loss: 1.4058, Training accuracy: 53.92,	Test Loss: 1.4632, Test Accuracy: 49.42,	Learning rate: 0.00100
# Epoch [51/100],	Training Loss: 1.2269, Training accuracy: 58.38,	Test Loss: 1.3745, Test Accuracy: 53.26,	Learning rate: 0.00001
# Epoch [52/100],	Training Loss: 1.2287, Training accuracy: 58.38,	Test Loss: 1.3744, Test Accuracy: 53.26,	Learning rate: 0.00001
# Epoch [53/100],	Training Loss: 1.2274, Training accuracy: 58.35,	Test Loss: 1.3744, Test Accuracy: 53.26,	Learning rate: 0.00001
# Epoch [54/100],	Training Loss: 1.2262, Training accuracy: 58.38,	Test Loss: 1.3744, Test Accuracy: 53.26,	Learning rate: 0.00001
# Epoch [55/100],	Training Loss: 1.2279, Training accuracy: 58.35,	Test Loss: 1.3743, Test Accuracy: 53.26,	Learning rate: 0.00001
# Epoch [56/100],	Training Loss: 1.2291, Training accuracy: 58.38,	Test Loss: 1.3743, Test Accuracy: 53.26,	Learning rate: 0.00001
# Epoch [57/100],	Training Loss: 1.2277, Training accuracy: 58.38,	Test Loss: 1.3743, Test Accuracy: 53.26,	Learning rate: 0.00001
# Epoch [58/100],	Training Loss: 1.2271, Training accuracy: 58.35,	Test Loss: 1.3742, Test Accuracy: 53.26,	Learning rate: 0.00001
# Epoch [59/100],	Training Loss: 1.2288, Training accuracy: 58.42,	Test Loss: 1.3742, Test Accuracy: 53.26,	Learning rate: 0.00001
# Epoch [60/100],	Training Loss: 1.2271, Training accuracy: 58.42,	Test Loss: 1.3742, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [61/100],	Training Loss: 1.2262, Training accuracy: 58.42,	Test Loss: 1.3742, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [62/100],	Training Loss: 1.2267, Training accuracy: 58.42,	Test Loss: 1.3741, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [63/100],	Training Loss: 1.2266, Training accuracy: 58.42,	Test Loss: 1.3741, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [64/100],	Training Loss: 1.2250, Training accuracy: 58.42,	Test Loss: 1.3741, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [65/100],	Training Loss: 1.2266, Training accuracy: 58.42,	Test Loss: 1.3741, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [66/100],	Training Loss: 1.2245, Training accuracy: 58.42,	Test Loss: 1.3741, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [67/100],	Training Loss: 1.2266, Training accuracy: 58.42,	Test Loss: 1.3741, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [68/100],	Training Loss: 1.2252, Training accuracy: 58.42,	Test Loss: 1.3741, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [69/100],	Training Loss: 1.2282, Training accuracy: 58.42,	Test Loss: 1.3741, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [70/100],	Training Loss: 1.2263, Training accuracy: 58.42,	Test Loss: 1.3741, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [71/100],	Training Loss: 1.2256, Training accuracy: 58.42,	Test Loss: 1.3741, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [72/100],	Training Loss: 1.2258, Training accuracy: 58.42,	Test Loss: 1.3741, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [73/100],	Training Loss: 1.2259, Training accuracy: 58.42,	Test Loss: 1.3741, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [74/100],	Training Loss: 1.2256, Training accuracy: 58.42,	Test Loss: 1.3741, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [75/100],	Training Loss: 1.2252, Training accuracy: 58.42,	Test Loss: 1.3741, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [76/100],	Training Loss: 1.2276, Training accuracy: 58.42,	Test Loss: 1.3741, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [77/100],	Training Loss: 1.2256, Training accuracy: 58.42,	Test Loss: 1.3741, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [78/100],	Training Loss: 1.2279, Training accuracy: 58.42,	Test Loss: 1.3741, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [79/100],	Training Loss: 1.2260, Training accuracy: 58.42,	Test Loss: 1.3741, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [80/100],	Training Loss: 1.2269, Training accuracy: 58.42,	Test Loss: 1.3741, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [81/100],	Training Loss: 1.2270, Training accuracy: 58.42,	Test Loss: 1.3741, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [82/100],	Training Loss: 1.2252, Training accuracy: 58.42,	Test Loss: 1.3741, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [83/100],	Training Loss: 1.2282, Training accuracy: 58.42,	Test Loss: 1.3741, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [84/100],	Training Loss: 1.2272, Training accuracy: 58.42,	Test Loss: 1.3741, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [85/100],	Training Loss: 1.2260, Training accuracy: 58.42,	Test Loss: 1.3741, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [86/100],	Training Loss: 1.2261, Training accuracy: 58.42,	Test Loss: 1.3741, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [87/100],	Training Loss: 1.2256, Training accuracy: 58.42,	Test Loss: 1.3741, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [88/100],	Training Loss: 1.2263, Training accuracy: 58.42,	Test Loss: 1.3741, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [89/100],	Training Loss: 1.2256, Training accuracy: 58.42,	Test Loss: 1.3741, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [90/100],	Training Loss: 1.2270, Training accuracy: 58.42,	Test Loss: 1.3741, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [91/100],	Training Loss: 1.2252, Training accuracy: 58.42,	Test Loss: 1.3741, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [92/100],	Training Loss: 1.2272, Training accuracy: 58.42,	Test Loss: 1.3741, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [93/100],	Training Loss: 1.2261, Training accuracy: 58.42,	Test Loss: 1.3741, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [94/100],	Training Loss: 1.2264, Training accuracy: 58.42,	Test Loss: 1.3741, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [95/100],	Training Loss: 1.2246, Training accuracy: 58.42,	Test Loss: 1.3741, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [96/100],	Training Loss: 1.2268, Training accuracy: 58.42,	Test Loss: 1.3741, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [97/100],	Training Loss: 1.2274, Training accuracy: 58.42,	Test Loss: 1.3741, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [98/100],	Training Loss: 1.2252, Training accuracy: 58.42,	Test Loss: 1.3741, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [99/100],	Training Loss: 1.2264, Training accuracy: 58.42,	Test Loss: 1.3741, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [100/100],	Training Loss: 1.2246, Training accuracy: 58.42,	Test Loss: 1.3741, Test Accuracy: 53.26,	Learning rate: 0.00000

# %% [markdown]
# ## K-Fold Cross-Validation on LSTM Model

# %% [markdown]
# Since LSTM is the model which performs best, we run cross validation for its hyperparameters

# %%
# Choosing hyperparameters
parameter_grid = {
    "dropout": [0.2],
    "learning_rate": [0.001, 0.01],
    "weight_decay": [0.01],
    "scheduler": ['StepLR'],
    "lambda_penalty": [0, 1e-5, 1e-2],
    "static_learnable": [True, False],
    "hidden_size": [32, 64]
}
# Load best parameters for static model
best_params_static = {
    "dropout": 0.25,
    "learning_rate": 0.001,
    "weight_decay": 0.01,
    "scheduler": "StepLR"
}


best_params, results = k_fold_cross_validation_dynamic(
    StaticModelMultibranch,
    LSTMDynamicModel,
    data,
    CrossEntropyWithTemporalSmoothness,
    parameter_grid,
    best_params_static,
    dynamic_params["num_epochs"],
    dynamic_params["patience"],
    params["batch_size"],
    device,
    k_folds=3,
    seed=seed,
    cross_validation_on_loss=True,
    verbose=True
)

results_file = 'cross_val_results_dynamic'
with open(results_file, 'w') as f:
    json.dump(results, f, indent=4)

best_file = 'best_results_dynamic'
with open(best_file, 'w') as f:
    json.dump(best_params, f, indent=4)

# %%
# Load hyperparameters
with open('hyperparameters_cross_val.json', 'r') as file:
    params = json.load(file)

static_params = params["static_model"]
dynamic_params = params["dynamic_model"]

# Set embedding dimensions based on json parameter
if static_params["long_embeddings"]:
    embedding_dim = 640
else:
    embedding_dim = 320

# %%
# Run training
train_loss, train_accuracy, test_loss, test_accuracy, dynamic_model = dynamic_training(num_features, num_classes, num_timesteps, embedding_dim, dynamic_params, static_model, dataloader_train, dataloader_test, verbose, device)
