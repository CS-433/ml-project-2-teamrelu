# %%
import torch
import torch.nn as nn
import json
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import train_test_split
from configs.dataloaders import create_data_loaders
from runner_static import static_training
from runner_dynamic import dynamic_training
from models.static_models.static_model_multibranch import StaticModelMultibranch
from models.dynamic_models.lstm_model import LSTMDynamicModel
from trainers.cross_validation import k_fold_cross_validation_static, k_fold_cross_validation_dynamic
from losses.losses import CrossEntropy, CrossEntropyWithLasso, CrossEntropyWithTemporalSmoothness

# %% [markdown]
# # Static Model

# %% [markdown]
# The main goal of this first part is to try different architectures and select the one that performs better for the **static protein localization problem**.
#
# We start by initializing all the indispensable variables and loading hyperparameters from `hyperparameters.json`. From now on, all the  __bold_variables__ are to be considered as taken from this JSON file.

# %%
# Initialize random seed
seed = 30026
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)

# Define dimensions of the problem
num_classes = 15
num_timesteps = 5
num_features = 34 # both static and dynamic

# Decide whever to be verbose with display outputs and set device
verbose = True
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Define hyperparameters
with open('hyperparameters/hyperparameters.json', 'r') as file:
    params = json.load(file)

static_params = params["static_model"]

# Load file
data = pd.read_csv(params["file_path"])

# %% [markdown]
# Since our models will be combined together for creating more complex models, we split data in train and validation sets once and for all before creating all models: in this way, we avoid the risk of using the same samples for train and for validate at the same time.

# %%
# Split dataset in train and test sets keeping balance for the static label localization
data_train, data_test = train_test_split(data, test_size=params["test_size"], random_state=seed, stratify = data['static_localization'])

# Create dataloaders
dataloader_train, dataloader_test = create_data_loaders(data_train, data_test, params["batch_size"])

# %% [markdown]
# ## First Model: Multi-Layer-Perceptron

# %% [markdown]
# Our first try is a simple MLP with just a hidden layer of size __intermediate_dim__, which takes as input the ESM-embeddings (you can choose between small and big embeddings with __long_embeddings__ boolean variable, depending on computational availabilities).
#
# We are using techniques for regularization which will be present in all our architectures: dropout, weight_decay, early stopping, layer normalization, weight initialization, learning rate scheduler.
#
# In this first phase, we only try some reasonable hyperparameters choices: because of high compuational costs, we cannot do cross-validation on all the hyperparameters for all the models, but we will do it for our best static model.

# %%
# Running the first model
train_loss, train_accuracy, test_loss, test_accuracy, static_model_dict = static_training(num_classes, static_params, dataloader_train, dataloader_test, verbose, device)
# Out:
# Starting training of StaticModelMLP
# Epoch [1/100],	Training Loss: 1.7331, Training accuracy: 42.29,	Test Loss: 1.4622, Test Accuracy: 50.92,	Learning rate: 0.01000
# Epoch [2/100],	Training Loss: 1.4092, Training accuracy: 51.18,	Test Loss: 1.3740, Test Accuracy: 52.05,	Learning rate: 0.01000
# Epoch [3/100],	Training Loss: 1.3264, Training accuracy: 54.39,	Test Loss: 1.3400, Test Accuracy: 54.58,	Learning rate: 0.01000
# Epoch [4/100],	Training Loss: 1.2435, Training accuracy: 57.14,	Test Loss: 1.3544, Test Accuracy: 53.88,	Learning rate: 0.01000
# Epoch [5/100],	Training Loss: 1.1846, Training accuracy: 59.26,	Test Loss: 1.2880, Test Accuracy: 54.87,	Learning rate: 0.01000
# Epoch [27/100],	Training Loss: 0.3351, Training accuracy: 87.37,	Test Loss: 1.6793, Test Accuracy: 57.55,	Learning rate: 0.00100
# Epoch [28/100],	Training Loss: 0.3392, Training accuracy: 87.80,	Test Loss: 1.6619, Test Accuracy: 56.56,	Learning rate: 0.00100
# Early stopping triggered after 28 epochs. Best test loss: 1.2863

# %% [markdown]
# Even though we have used some technique like __dropout__, __weight_decay__ and early stopping (set with __patience__ parameter), this model appears to strongly overfit.

# %% [markdown]
# ## Second Model: XGBoost

# %% [markdown]
# Commento di Riki aaaaaa
#
# Since XGBoost has a different architecture, we will use an appositely create JSON file `hyperparametersxgb.json`.

# %%
# Define hyperparameters
with open('hyperparametersxgb.json', 'r') as file:
    xgb_params = json.load(file)

xgb_params = xgb_params["static_model"]

# %%
# Running the second model
train_loss, train_accuracy, test_loss, test_accuracy, static_model_dict = static_training(num_classes, xgb_params, dataloader_train, dataloader_test, verbose, device)
# Out:
# Starting training of XGBoost
# [0]	train-mlogloss:2.70180	train-merror:0.37500	test-mlogloss:2.70669	test-merror:0.81250
# [25]	train-mlogloss:2.55404	train-merror:0.34375	test-mlogloss:2.66291	test-merror:0.75000
# [50]	train-mlogloss:2.42204	train-merror:0.34375	test-mlogloss:2.61855	test-merror:0.75000
# [75]	train-mlogloss:2.30472	train-merror:0.34375	test-mlogloss:2.58300	test-merror:0.75000
# [100]	train-mlogloss:2.19836	train-merror:0.37500	test-mlogloss:2.55792	test-merror:0.71875
# [125]	train-mlogloss:2.10559	train-merror:0.37500	test-mlogloss:2.53734	test-merror:0.71875
# [150]	train-mlogloss:2.02557	train-merror:0.37500	test-mlogloss:2.51902	test-merror:0.68750
# [175]	train-mlogloss:1.95740	train-merror:0.37500	test-mlogloss:2.50267	test-merror:0.68750
# [200]	train-mlogloss:1.91222	train-merror:0.37500	test-mlogloss:2.48511	test-merror:0.68750
# [225]	train-mlogloss:1.87771	train-merror:0.37500	test-mlogloss:2.46554	test-merror:0.68750
# [250]	train-mlogloss:1.84771	train-merror:0.37500	test-mlogloss:2.44755	test-merror:0.68750
# [275]	train-mlogloss:1.82149	train-merror:0.37500	test-mlogloss:2.43197	test-merror:0.68750
# [300]	train-mlogloss:1.80726	train-merror:0.40625	test-mlogloss:2.41427	test-merror:0.71875
# [325]	train-mlogloss:1.79629	train-merror:0.40625	test-mlogloss:2.39782	test-merror:0.71875
# [350]	train-mlogloss:1.78658	train-merror:0.40625	test-mlogloss:2.38287	test-merror:0.71875
# [375]	train-mlogloss:1.77794	train-merror:0.40625	test-mlogloss:2.36924	test-merror:0.71875
# [400]	train-mlogloss:1.77022	train-merror:0.40625	test-mlogloss:2.35677	test-merror:0.71875
# [425]	train-mlogloss:1.76331	train-merror:0.40625	test-mlogloss:2.34535	test-merror:0.71875
# [450]	train-mlogloss:1.75710	train-merror:0.40625	test-mlogloss:2.33486	test-merror:0.75000
# [475]	train-mlogloss:1.75149	train-merror:0.40625	test-mlogloss:2.32520	test-merror:0.75000
# [500]	train-mlogloss:1.74642	train-merror:0.40625	test-mlogloss:2.31630	test-merror:0.75000
# [525]	train-mlogloss:1.74183	train-merror:0.40625	test-mlogloss:2.30808	test-merror:0.75000
# [550]	train-mlogloss:1.73766	train-merror:0.40625	test-mlogloss:2.30048	test-merror:0.75000
# [575]	train-mlogloss:1.73386	train-merror:0.40625	test-mlogloss:2.29344	test-merror:0.75000
# [600]	train-mlogloss:1.73040	train-merror:0.40625	test-mlogloss:2.28693	test-merror:0.75000
# [625]	train-mlogloss:1.72724	train-merror:0.40625	test-mlogloss:2.28089	test-merror:0.75000
# [650]	train-mlogloss:1.72435	train-merror:0.40625	test-mlogloss:2.27529	test-merror:0.75000
# [675]	train-mlogloss:1.72170	train-merror:0.40625	test-mlogloss:2.27009	test-merror:0.75000
# [700]	train-mlogloss:1.71927	train-merror:0.40625	test-mlogloss:2.26526	test-merror:0.75000
# [725]	train-mlogloss:1.71704	train-merror:0.40625	test-mlogloss:2.26077	test-merror:0.75000
# [750]	train-mlogloss:1.71499	train-merror:0.40625	test-mlogloss:2.25660	test-merror:0.75000
# [775]	train-mlogloss:1.71311	train-merror:0.40625	test-mlogloss:2.25272	test-merror:0.75000
# [800]	train-mlogloss:1.71137	train-merror:0.40625	test-mlogloss:2.24911	test-merror:0.75000
# [825]	train-mlogloss:1.70977	train-merror:0.40625	test-mlogloss:2.24576	test-merror:0.75000
# [850]	train-mlogloss:1.70830	train-merror:0.40625	test-mlogloss:2.24263	test-merror:0.75000
# [875]	train-mlogloss:1.70694	train-merror:0.40625	test-mlogloss:2.23973	test-merror:0.75000
# [900]	train-mlogloss:1.70568	train-merror:0.40625	test-mlogloss:2.23702	test-merror:0.75000
# [925]	train-mlogloss:1.70452	train-merror:0.40625	test-mlogloss:2.23450	test-merror:0.75000
# [950]	train-mlogloss:1.70345	train-merror:0.40625	test-mlogloss:2.23215	test-merror:0.75000
# [975]	train-mlogloss:1.70246	train-merror:0.40625	test-mlogloss:2.22997	test-merror:0.75000
# [999]	train-mlogloss:1.70158	train-merror:0.40625	test-mlogloss:2.22801	test-merror:0.75000

# %% [markdown]
# ## Third Model: StaticModelMultibranch

# %% [markdown]
# The last static models is created with more complex architecture: since from biological analysis we expect the first and last amino acids of each sequence to be the most representative for our task, this neural networks takes as input also the strings of first and last 20 amino acids of each sequence. These strings are embedded by some transformer layers and then given to some MLP layer together with ESM-embeddings.

# %% [markdown]
# ### Training

# %%
# Change model_type for running the right model (from 0 to 2, for more info look at static_training inside runner_static.py)
static_params["model_type"] +=2

# %%
# Running the third model
train_loss, train_accuracy, test_loss, test_accuracy, static_model_dict = static_training(num_classes, static_params, dataloader_train, dataloader_test, verbose, device)
# Out:
# Starting training of StaticModelMultibranch
# Epoch [1/100],	Training Loss: 2.3416, Training accuracy: 29.95,	Test Loss: 1.7508, Test Accuracy: 36.67,	Learning rate: 0.01000
# Epoch [2/100],	Training Loss: 1.7370, Training accuracy: 38.98,	Test Loss: 1.5143, Test Accuracy: 47.53,	Learning rate: 0.01000
# Epoch [24/100],	Training Loss: 0.8607, Training accuracy: 68.89,	Test Loss: 1.3607, Test Accuracy: 57.83,	Learning rate: 0.00100
# Epoch [25/100],	Training Loss: 0.8426, Training accuracy: 69.31,	Test Loss: 1.3693, Test Accuracy: 57.26,	Learning rate: 0.00100
# Epoch [26/100],	Training Loss: 0.8352, Training accuracy: 69.31,	Test Loss: 1.3647, Test Accuracy: 57.55,	Learning rate: 0.00100
# Epoch [27/100],	Training Loss: 0.8172, Training accuracy: 70.26,	Test Loss: 1.3856, Test Accuracy: 56.56,	Learning rate: 0.00100
# Epoch [28/100],	Training Loss: 0.7892, Training accuracy: 71.25,	Test Loss: 1.4057, Test Accuracy: 57.97,	Learning rate: 0.00100
# Epoch [29/100],	Training Loss: 0.7926, Training accuracy: 71.18,	Test Loss: 1.4306, Test Accuracy: 57.83,	Learning rate: 0.00100
# Epoch [30/100],	Training Loss: 0.7722, Training accuracy: 71.36,	Test Loss: 1.4732, Test Accuracy: 57.69,	Learning rate: 0.00100
# Epoch [31/100],	Training Loss: 0.7641, Training accuracy: 71.25,	Test Loss: 1.4291, Test Accuracy: 58.11,	Learning rate: 0.00100
# Epoch [32/100],	Training Loss: 0.7342, Training accuracy: 73.12,	Test Loss: 1.5055, Test Accuracy: 58.11,	Learning rate: 0.00100
# Epoch [33/100],	Training Loss: 0.7289, Training accuracy: 72.77,	Test Loss: 1.4636, Test Accuracy: 57.97,	Learning rate: 0.00100
# Epoch [34/100],	Training Loss: 0.7355, Training accuracy: 72.91,	Test Loss: 1.4831, Test Accuracy: 57.40,	Learning rate: 0.00100
# Early stopping triggered after 34 epochs. Best test loss: 1.3038

# %% [markdown]
# By analyzing our main metrics (validation loss and validation accuracy) and the behavior in terms of overfitting, we can conclude that this is the best static model we have created.
# For this reason, we perform k-fold cross-validation for finding the best hyperparameters of our model.

# %% [markdown]
# ### K-Fold Cross validation

# %%
# Choose parameters for grid cross-validation
parameter_grid = {
    "dropout": [0, 0.25, 0.5],
    "learning_rate": [0.001, 0.01],
    "weight_decay": [0, 0.0001, 0.01],
    "scheduler": ['CosineAnnealingLR', 'StepLR', 'ExponentialLR']
}

# Setting principal fixed parameters for k-fold (i.e. number of folds and metric to use for choosing best model)
k_folds = 3
cross_validation_on_loss = True

best_params, results = k_fold_cross_validation_static(
    StaticModelMultibranch,
    data,
    CrossEntropy,
    parameter_grid,
    static_params["num_epochs"],
    static_params["patience"],
    params["batch_size"],
    device,
    k_folds=k_folds,
    seed=seed,
    cross_validation_on_loss=cross_validation_on_loss,
    verbose=True
)

# %%
# We save best results in a json file for using them in a second moment
results_file = 'hyperparameters/cross_val_results_static'
with open(results_file, 'w') as f:
    json.dump(results, f, indent=4)

best_file = 'hyperparameters/best_results_static'
with open(best_file, 'w') as f:
    json.dump(best_params, f, indent=4)

# %% [markdown]
# Starting from this parameters, we create a new `hyperparameters_cross_validation.json` file for running our best model on the hyperparameters obtained with 3-fold cross-validation. The result of this training will be our best static architecture and will be used in the second part of the project.

# %%
# Load hyperparameters
with open('hyperparameters/hyperparameters_cross_val.json', 'r') as file:
    params = json.load(file)

static_params = params["static_model"]

# Set embedding dimensions based on json parameter
if static_params["long_embeddings"]:
    embedding_dim = 640
else:
    embedding_dim = 320

# %%
# Running the third model
train_loss, train_accuracy, test_loss, test_accuracy, static_model_dict = static_training(num_classes, static_params, dataloader_train, dataloader_test, verbose, device)
# Out:
# Starting training of StaticModelMultibranch
# Epoch [1/100],	Training Loss: 2.3817, Training accuracy: 28.96,	Test Loss: 1.8273, Test Accuracy: 37.80,	Learning rate: 0.00100
# Epoch [2/100],	Training Loss: 1.8299, Training accuracy: 37.85,	Test Loss: 1.6242, Test Accuracy: 43.58,	Learning rate: 0.00100
# Epoch [3/100],	Training Loss: 1.6489, Training accuracy: 43.53,	Test Loss: 1.4827, Test Accuracy: 47.81,	Learning rate: 0.00100
# Epoch [4/100],	Training Loss: 1.5480, Training accuracy: 47.37,	Test Loss: 1.4253, Test Accuracy: 50.35,	Learning rate: 0.00100
# Epoch [5/100],	Training Loss: 1.4712, Training accuracy: 50.19,	Test Loss: 1.3841, Test Accuracy: 52.47,	Learning rate: 0.00100
# Epoch [6/100],	Training Loss: 1.4236, Training accuracy: 52.70,	Test Loss: 1.3824, Test Accuracy: 51.20,	Learning rate: 0.00100
# Epoch [7/100],	Training Loss: 1.3812, Training accuracy: 53.37,	Test Loss: 1.3482, Test Accuracy: 52.89,	Learning rate: 0.00100
# Epoch [8/100],	Training Loss: 1.3297, Training accuracy: 54.32,	Test Loss: 1.3460, Test Accuracy: 53.60,	Learning rate: 0.00100
# Epoch [9/100],	Training Loss: 1.2800, Training accuracy: 56.58,	Test Loss: 1.3310, Test Accuracy: 55.99,	Learning rate: 0.00100
# Epoch [10/100],	Training Loss: 1.2322, Training accuracy: 58.17,	Test Loss: 1.3208, Test Accuracy: 54.02,	Learning rate: 0.00100
# Epoch [11/100],	Training Loss: 1.2023, Training accuracy: 59.08,	Test Loss: 1.2998, Test Accuracy: 55.43,	Learning rate: 0.00100
# Epoch [12/100],	Training Loss: 1.1799, Training accuracy: 59.72,	Test Loss: 1.3163, Test Accuracy: 55.85,	Learning rate: 0.00100
# Epoch [13/100],	Training Loss: 1.1335, Training accuracy: 60.42,	Test Loss: 1.3072, Test Accuracy: 56.28,	Learning rate: 0.00100
# Epoch [14/100],	Training Loss: 1.1097, Training accuracy: 60.18,	Test Loss: 1.2989, Test Accuracy: 56.56,	Learning rate: 0.00100
# Epoch [15/100],	Training Loss: 1.0949, Training accuracy: 61.41,	Test Loss: 1.3338, Test Accuracy: 56.84,	Learning rate: 0.00100
# Epoch [16/100],	Training Loss: 1.0558, Training accuracy: 62.22,	Test Loss: 1.3018, Test Accuracy: 57.40,	Learning rate: 0.00100
# Epoch [17/100],	Training Loss: 1.0053, Training accuracy: 63.70,	Test Loss: 1.2991, Test Accuracy: 58.82,	Learning rate: 0.00100
# Epoch [18/100],	Training Loss: 1.0007, Training accuracy: 63.99,	Test Loss: 1.3070, Test Accuracy: 58.82,	Learning rate: 0.00100
# Epoch [19/100],	Training Loss: 0.9903, Training accuracy: 63.42,	Test Loss: 1.3466, Test Accuracy: 57.55,	Learning rate: 0.00100
# Epoch [20/100],	Training Loss: 0.9426, Training accuracy: 66.00,	Test Loss: 1.3488, Test Accuracy: 57.26,	Learning rate: 0.00010
# Epoch [21/100],	Training Loss: 0.8663, Training accuracy: 68.32,	Test Loss: 1.3337, Test Accuracy: 58.53,	Learning rate: 0.00010
# Epoch [22/100],	Training Loss: 0.8161, Training accuracy: 70.93,	Test Loss: 1.3365, Test Accuracy: 58.82,	Learning rate: 0.00010
# Epoch [23/100],	Training Loss: 0.7761, Training accuracy: 71.64,	Test Loss: 1.3544, Test Accuracy: 58.67,	Learning rate: 0.00010
# Epoch [24/100],	Training Loss: 0.7905, Training accuracy: 70.79,	Test Loss: 1.3384, Test Accuracy: 58.39,	Learning rate: 0.00010
# Epoch [25/100],	Training Loss: 0.7559, Training accuracy: 72.95,	Test Loss: 1.3678, Test Accuracy: 59.80,	Learning rate: 0.00010
# Epoch [26/100],	Training Loss: 0.7733, Training accuracy: 71.60,	Test Loss: 1.3569, Test Accuracy: 59.24,	Learning rate: 0.00010
# Epoch [27/100],	Training Loss: 0.7721, Training accuracy: 71.89,	Test Loss: 1.3618, Test Accuracy: 58.82,	Learning rate: 0.00010
# Epoch [28/100],	Training Loss: 0.7487, Training accuracy: 73.05,	Test Loss: 1.3753, Test Accuracy: 60.37,	Learning rate: 0.00010
# Epoch [29/100],	Training Loss: 0.7403, Training accuracy: 73.23,	Test Loss: 1.3622, Test Accuracy: 59.10,	Learning rate: 0.00010
# Epoch [30/100],	Training Loss: 0.7536, Training accuracy: 71.78,	Test Loss: 1.3828, Test Accuracy: 58.11,	Learning rate: 0.00010
# Epoch [31/100],	Training Loss: 0.7468, Training accuracy: 73.37,	Test Loss: 1.3768, Test Accuracy: 59.10,	Learning rate: 0.00010
# Epoch [32/100],	Training Loss: 0.7352, Training accuracy: 73.16,	Test Loss: 1.3908, Test Accuracy: 59.38,	Learning rate: 0.00010
# Epoch [33/100],	Training Loss: 0.7349, Training accuracy: 73.40,	Test Loss: 1.3841, Test Accuracy: 59.38,	Learning rate: 0.00010
# Epoch [34/100],	Training Loss: 0.7084, Training accuracy: 74.53,	Test Loss: 1.3843, Test Accuracy: 59.24,	Learning rate: 0.00010
# Early stopping triggered after 34 epochs. Best test loss: 1.2989

# %%
# Save best model
best_static_model = StaticModelMultibranch(num_classes=num_classes, embedding_dim=embedding_dim, extremities_dim=20, char_vocab_size=20, char_embed_dim=16, intermediate_dim=static_params["intermediate_dim"], dropout=static_params["dropout"])

# Load the weights from the dictionary
best_static_model.load_state_dict(static_model_dict)
# Out:
# <All keys matched successfully>

# %% [markdown]
# # Dynamic Model

# %% [markdown]
# In this second part, we try to solve the dynamic counterpart of the localization problem: every protein can now change position during eukaryotic cell cycle, which consists of 5 different timesteps.

# %% [markdown]
# ## First Model: LSTMDynamicModel

# %% [markdown]
# The first model consists of a LSTM architecture which takes as input the dynamic data and the output of the StaticModelMultibranch static model.

# %%
# Load hyperparameters
dynamic_params = params["dynamic_model"]

# %%
# Run training
train_loss, train_accuracy, test_loss, test_accuracy, lstm_dynamic_model = dynamic_training(num_features, num_classes, num_timesteps, embedding_dim, dynamic_params, best_static_model, dataloader_train, dataloader_test, verbose, device)
# Out:
# Starting training of LSTMDynamicModel
# Epoch [1/100],	Training Loss: 1.8943, Training accuracy: 37.95,	Test Loss: 1.7395, Test Accuracy: 47.08,	Learning rate: 0.00100
# Epoch [2/100],	Training Loss: 1.2698, Training accuracy: 58.98,	Test Loss: 1.5588, Test Accuracy: 54.50,	Learning rate: 0.00100
# Epoch [3/100],	Training Loss: 1.1127, Training accuracy: 64.35,	Test Loss: 1.4961, Test Accuracy: 54.95,	Learning rate: 0.00100
# Epoch [4/100],	Training Loss: 1.0494, Training accuracy: 66.31,	Test Loss: 1.4771, Test Accuracy: 55.74,	Learning rate: 0.00100
# Epoch [5/100],	Training Loss: 1.0242, Training accuracy: 67.76,	Test Loss: 1.4700, Test Accuracy: 56.61,	Learning rate: 0.00100
# Epoch [6/100],	Training Loss: 0.9778, Training accuracy: 70.65,	Test Loss: 1.3960, Test Accuracy: 58.00,	Learning rate: 0.00100
# Epoch [7/100],	Training Loss: 0.9579, Training accuracy: 71.36,	Test Loss: 1.4611, Test Accuracy: 57.66,	Learning rate: 0.00100
# Epoch [8/100],	Training Loss: 0.9442, Training accuracy: 71.32,	Test Loss: 1.4164, Test Accuracy: 57.80,	Learning rate: 0.00100
# Epoch [9/100],	Training Loss: 0.9241, Training accuracy: 71.44,	Test Loss: 1.3725, Test Accuracy: 58.73,	Learning rate: 0.00100
# Epoch [10/100],	Training Loss: 0.9128, Training accuracy: 72.71,	Test Loss: 1.3748, Test Accuracy: 58.59,	Learning rate: 0.00100
# Epoch [11/100],	Training Loss: 0.9019, Training accuracy: 72.54,	Test Loss: 1.3778, Test Accuracy: 57.43,	Learning rate: 0.00100
# Epoch [12/100],	Training Loss: 0.8825, Training accuracy: 72.08,	Test Loss: 1.3729, Test Accuracy: 58.08,	Learning rate: 0.00100
# Epoch [13/100],	Training Loss: 0.8611, Training accuracy: 73.35,	Test Loss: 1.3847, Test Accuracy: 58.31,	Learning rate: 0.00100
# Epoch [14/100],	Training Loss: 0.8817, Training accuracy: 72.56,	Test Loss: 1.3914, Test Accuracy: 58.70,	Learning rate: 0.00100
# Epoch [15/100],	Training Loss: 0.8539, Training accuracy: 74.05,	Test Loss: 1.4232, Test Accuracy: 58.48,	Learning rate: 0.00100
# Epoch [16/100],	Training Loss: 0.8553, Training accuracy: 73.63,	Test Loss: 1.3775, Test Accuracy: 58.67,	Learning rate: 0.00100
# Epoch [17/100],	Training Loss: 0.8777, Training accuracy: 73.09,	Test Loss: 1.3137, Test Accuracy: 58.48,	Learning rate: 0.00100
# Epoch [18/100],	Training Loss: 0.8306, Training accuracy: 74.00,	Test Loss: 1.3727, Test Accuracy: 58.65,	Learning rate: 0.00100
# Epoch [19/100],	Training Loss: 0.8351, Training accuracy: 73.85,	Test Loss: 1.3413, Test Accuracy: 58.14,	Learning rate: 0.00100
# Epoch [20/100],	Training Loss: 0.8372, Training accuracy: 73.93,	Test Loss: 1.3552, Test Accuracy: 59.29,	Learning rate: 0.00010
# Epoch [21/100],	Training Loss: 0.8262, Training accuracy: 74.29,	Test Loss: 1.3596, Test Accuracy: 58.28,	Learning rate: 0.00010
# Epoch [22/100],	Training Loss: 0.8129, Training accuracy: 75.36,	Test Loss: 1.3542, Test Accuracy: 58.42,	Learning rate: 0.00010
# Epoch [23/100],	Training Loss: 0.8219, Training accuracy: 73.69,	Test Loss: 1.3437, Test Accuracy: 58.14,	Learning rate: 0.00010
# Epoch [24/100],	Training Loss: 0.8276, Training accuracy: 73.32,	Test Loss: 1.3369, Test Accuracy: 58.36,	Learning rate: 0.00010
# Epoch [25/100],	Training Loss: 0.8360, Training accuracy: 73.19,	Test Loss: 1.3244, Test Accuracy: 58.62,	Learning rate: 0.00010
# Epoch [26/100],	Training Loss: 0.8293, Training accuracy: 74.07,	Test Loss: 1.3360, Test Accuracy: 58.00,	Learning rate: 0.00010
# Epoch [27/100],	Training Loss: 0.7966, Training accuracy: 74.39,	Test Loss: 1.3428, Test Accuracy: 58.28,	Learning rate: 0.00010
# Epoch [28/100],	Training Loss: 0.8058, Training accuracy: 74.20,	Test Loss: 1.3402, Test Accuracy: 58.82,	Learning rate: 0.00010
# Epoch [29/100],	Training Loss: 0.8293, Training accuracy: 74.83,	Test Loss: 1.3448, Test Accuracy: 58.25,	Learning rate: 0.00010
# Epoch [30/100],	Training Loss: 0.7882, Training accuracy: 75.88,	Test Loss: 1.3424, Test Accuracy: 58.39,	Learning rate: 0.00010
# Epoch [31/100],	Training Loss: 0.8229, Training accuracy: 73.63,	Test Loss: 1.3382, Test Accuracy: 58.39,	Learning rate: 0.00010
# Epoch [32/100],	Training Loss: 0.8006, Training accuracy: 75.09,	Test Loss: 1.3392, Test Accuracy: 58.67,	Learning rate: 0.00010
# Epoch [33/100],	Training Loss: 0.8245, Training accuracy: 73.72,	Test Loss: 1.3353, Test Accuracy: 58.67,	Learning rate: 0.00010
# Epoch [34/100],	Training Loss: 0.7930, Training accuracy: 75.53,	Test Loss: 1.3449, Test Accuracy: 58.53,	Learning rate: 0.00010
# Epoch [35/100],	Training Loss: 0.8130, Training accuracy: 74.39,	Test Loss: 1.3403, Test Accuracy: 58.36,	Learning rate: 0.00010
# Epoch [36/100],	Training Loss: 0.8276, Training accuracy: 73.14,	Test Loss: 1.3441, Test Accuracy: 58.67,	Learning rate: 0.00010
# Epoch [37/100],	Training Loss: 0.8171, Training accuracy: 74.33,	Test Loss: 1.3423, Test Accuracy: 58.96,	Learning rate: 0.00010
# Early stopping triggered after 37 epochs. Best test loss: 1.3137

# %% [markdown]
# ## Second Model: TCNModel

# %%
# Change model_type for running the right model (from 0 to 1, for more info look at dynamic_training inside runner_dynamic.py)
dynamic_params["model_type"] +=1

# %%
# Run training
train_loss, train_accuracy, test_loss, test_accuracy, dynamic_model = dynamic_training(num_features, num_classes, num_timesteps, embedding_dim, dynamic_params, best_static_model, dataloader_train, dataloader_test, verbose, device)
# Out:
# Starting training of TCNDynamicModel
# Epoch [1/100],	Training Loss: 1.8005, Training accuracy: 39.52,	Test Loss: 1.4539, Test Accuracy: 54.75,	Learning rate: 0.00100
# Epoch [2/100],	Training Loss: 1.3470, Training accuracy: 55.35,	Test Loss: 1.3867, Test Accuracy: 55.20,	Learning rate: 0.00100
# Epoch [3/100],	Training Loss: 1.2171, Training accuracy: 60.29,	Test Loss: 1.3681, Test Accuracy: 57.46,	Learning rate: 0.00100
# Epoch [4/100],	Training Loss: 1.1343, Training accuracy: 61.94,	Test Loss: 1.2846, Test Accuracy: 59.58,	Learning rate: 0.00100
# Epoch [5/100],	Training Loss: 1.0588, Training accuracy: 64.21,	Test Loss: 1.3477, Test Accuracy: 59.15,	Learning rate: 0.00100
# Epoch [6/100],	Training Loss: 0.9958, Training accuracy: 66.94,	Test Loss: 1.3375, Test Accuracy: 58.82,	Learning rate: 0.00100
# Epoch [7/100],	Training Loss: 0.9633, Training accuracy: 67.29,	Test Loss: 1.3150, Test Accuracy: 59.69,	Learning rate: 0.00100
# Epoch [8/100],	Training Loss: 0.8904, Training accuracy: 69.15,	Test Loss: 1.2875, Test Accuracy: 60.14,	Learning rate: 0.00100
# Epoch [9/100],	Training Loss: 0.8739, Training accuracy: 70.25,	Test Loss: 1.3184, Test Accuracy: 59.75,	Learning rate: 0.00100
# Epoch [10/100],	Training Loss: 0.8292, Training accuracy: 71.51,	Test Loss: 1.3437, Test Accuracy: 58.11,	Learning rate: 0.00100
# Epoch [11/100],	Training Loss: 0.8111, Training accuracy: 71.76,	Test Loss: 1.4281, Test Accuracy: 59.97,	Learning rate: 0.00100
# Epoch [12/100],	Training Loss: 0.7869, Training accuracy: 73.04,	Test Loss: 1.3148, Test Accuracy: 60.68,	Learning rate: 0.00100
# Epoch [13/100],	Training Loss: 0.7402, Training accuracy: 74.85,	Test Loss: 1.3741, Test Accuracy: 58.65,	Learning rate: 0.00100
# Epoch [14/100],	Training Loss: 0.7284, Training accuracy: 74.48,	Test Loss: 1.4077, Test Accuracy: 60.23,	Learning rate: 0.00100
# Epoch [15/100],	Training Loss: 0.7128, Training accuracy: 75.66,	Test Loss: 1.3937, Test Accuracy: 58.48,	Learning rate: 0.00100
# Epoch [16/100],	Training Loss: 0.6828, Training accuracy: 76.83,	Test Loss: 1.3813, Test Accuracy: 59.49,	Learning rate: 0.00100
# Epoch [17/100],	Training Loss: 0.6435, Training accuracy: 77.88,	Test Loss: 1.3815, Test Accuracy: 60.11,	Learning rate: 0.00100
# Epoch [18/100],	Training Loss: 0.6470, Training accuracy: 77.06,	Test Loss: 1.4851, Test Accuracy: 59.80,	Learning rate: 0.00100
# Epoch [19/100],	Training Loss: 0.6392, Training accuracy: 77.45,	Test Loss: 1.3926, Test Accuracy: 59.52,	Learning rate: 0.00100
# Epoch [20/100],	Training Loss: 0.6097, Training accuracy: 78.44,	Test Loss: 1.4440, Test Accuracy: 58.39,	Learning rate: 0.00010
# Epoch [21/100],	Training Loss: 0.5369, Training accuracy: 81.64,	Test Loss: 1.4634, Test Accuracy: 60.28,	Learning rate: 0.00010
# Epoch [22/100],	Training Loss: 0.4972, Training accuracy: 82.85,	Test Loss: 1.4736, Test Accuracy: 60.39,	Learning rate: 0.00010
# Epoch [23/100],	Training Loss: 0.4899, Training accuracy: 83.22,	Test Loss: 1.4678, Test Accuracy: 60.25,	Learning rate: 0.00010
# Epoch [24/100],	Training Loss: 0.4854, Training accuracy: 83.99,	Test Loss: 1.4911, Test Accuracy: 60.51,	Learning rate: 0.00010
# Early stopping triggered after 24 epochs. Best test loss: 1.2846

# %% [markdown]
# ## Third Model: SimpleModel

# %%
# Change model_type for running the right model (from 1 to 2, for more info look at dynamic_training inside runner_dynamic.py)
dynamic_params["model_type"] +=1

# %%
# Run training
train_loss, train_accuracy, test_loss, test_accuracy, model = dynamic_training(num_features, num_classes, num_timesteps, embedding_dim, dynamic_params, best_static_model, dataloader_train, dataloader_test, verbose, device)
# Out:
# Starting training of SimpleDynamicModel
# Epoch [1/100],	Training Loss: 2.0316, Training accuracy: 32.96,	Test Loss: 1.8351, Test Accuracy: 38.67,	Learning rate: 0.00100
# Epoch [2/100],	Training Loss: 1.7627, Training accuracy: 40.25,	Test Loss: 1.7207, Test Accuracy: 41.30,	Learning rate: 0.00100
# Epoch [3/100],	Training Loss: 1.6638, Training accuracy: 43.08,	Test Loss: 1.6523, Test Accuracy: 41.24,	Learning rate: 0.00100
# Epoch [4/100],	Training Loss: 1.5875, Training accuracy: 46.97,	Test Loss: 1.5945, Test Accuracy: 45.36,	Learning rate: 0.00100
# Epoch [5/100],	Training Loss: 1.5337, Training accuracy: 48.99,	Test Loss: 1.5590, Test Accuracy: 45.70,	Learning rate: 0.00100
# Epoch [6/100],	Training Loss: 1.4924, Training accuracy: 50.97,	Test Loss: 1.5256, Test Accuracy: 47.79,	Learning rate: 0.00100
# Epoch [7/100],	Training Loss: 1.4590, Training accuracy: 52.02,	Test Loss: 1.5005, Test Accuracy: 49.17,	Learning rate: 0.00100
# Epoch [8/100],	Training Loss: 1.4309, Training accuracy: 53.48,	Test Loss: 1.4801, Test Accuracy: 48.69,	Learning rate: 0.00100
# Epoch [9/100],	Training Loss: 1.4053, Training accuracy: 53.63,	Test Loss: 1.4671, Test Accuracy: 49.73,	Learning rate: 0.00100
# Epoch [10/100],	Training Loss: 1.3852, Training accuracy: 54.03,	Test Loss: 1.4530, Test Accuracy: 50.47,	Learning rate: 0.00100
# Epoch [11/100],	Training Loss: 1.3664, Training accuracy: 55.49,	Test Loss: 1.4379, Test Accuracy: 50.41,	Learning rate: 0.00100
# Epoch [12/100],	Training Loss: 1.3475, Training accuracy: 55.41,	Test Loss: 1.4301, Test Accuracy: 51.26,	Learning rate: 0.00100
# Epoch [13/100],	Training Loss: 1.3337, Training accuracy: 55.63,	Test Loss: 1.4246, Test Accuracy: 51.17,	Learning rate: 0.00100
# Epoch [76/100],	Training Loss: 1.2280, Training accuracy: 58.46,	Test Loss: 1.3749, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [77/100],	Training Loss: 1.2255, Training accuracy: 58.46,	Test Loss: 1.3749, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [78/100],	Training Loss: 1.2269, Training accuracy: 58.46,	Test Loss: 1.3749, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [79/100],	Training Loss: 1.2262, Training accuracy: 58.46,	Test Loss: 1.3749, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [80/100],	Training Loss: 1.2263, Training accuracy: 58.46,	Test Loss: 1.3749, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [81/100],	Training Loss: 1.2248, Training accuracy: 58.46,	Test Loss: 1.3749, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [82/100],	Training Loss: 1.2254, Training accuracy: 58.46,	Test Loss: 1.3749, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [83/100],	Training Loss: 1.2268, Training accuracy: 58.46,	Test Loss: 1.3749, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [84/100],	Training Loss: 1.2269, Training accuracy: 58.46,	Test Loss: 1.3749, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [85/100],	Training Loss: 1.2270, Training accuracy: 58.46,	Test Loss: 1.3749, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [86/100],	Training Loss: 1.2286, Training accuracy: 58.46,	Test Loss: 1.3749, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [87/100],	Training Loss: 1.2250, Training accuracy: 58.46,	Test Loss: 1.3749, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [88/100],	Training Loss: 1.2259, Training accuracy: 58.46,	Test Loss: 1.3749, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [89/100],	Training Loss: 1.2267, Training accuracy: 58.46,	Test Loss: 1.3749, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [90/100],	Training Loss: 1.2288, Training accuracy: 58.46,	Test Loss: 1.3749, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [91/100],	Training Loss: 1.2270, Training accuracy: 58.46,	Test Loss: 1.3749, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [92/100],	Training Loss: 1.2263, Training accuracy: 58.46,	Test Loss: 1.3749, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [93/100],	Training Loss: 1.2261, Training accuracy: 58.46,	Test Loss: 1.3749, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [94/100],	Training Loss: 1.2262, Training accuracy: 58.46,	Test Loss: 1.3749, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [95/100],	Training Loss: 1.2252, Training accuracy: 58.46,	Test Loss: 1.3749, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [96/100],	Training Loss: 1.2262, Training accuracy: 58.46,	Test Loss: 1.3749, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [97/100],	Training Loss: 1.2261, Training accuracy: 58.46,	Test Loss: 1.3749, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [98/100],	Training Loss: 1.2262, Training accuracy: 58.46,	Test Loss: 1.3749, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [99/100],	Training Loss: 1.2245, Training accuracy: 58.46,	Test Loss: 1.3749, Test Accuracy: 53.26,	Learning rate: 0.00000
# Epoch [100/100],	Training Loss: 1.2260, Training accuracy: 58.46,	Test Loss: 1.3749, Test Accuracy: 53.26,	Learning rate: 0.00000

# %% [markdown]
# Important remarks can be done on this model: since it is not accounting for temporal relationships between data, it is not performing as well as the other models (as expected). However, it is still learning relatively well. This can be caused by the fact that ESM-embeddings are the most usefull data we have in our dataset, since they are obtained from elaborated architecture pre-trained on milions of proteins.

# %% [markdown]
# ## K-Fold Cross-Validation on LSTM Model

# %% [markdown]
# Since LSTM is the model which performs best, we run cross validation for its hyperparameters

# %%
# Choosing hyperparameters
parameter_grid = {
    "dropout": [0.2],
    "learning_rate": [0.001, 0.01],
    "weight_decay": [0.01],
    "scheduler": ['StepLR'],
    "lambda_penalty": [0, 1e-5, 1e-2],
    "static_learnable": [True, False],
    "hidden_size": [32, 64]
}

# Load best parameters for static model
with open('hyperparameters/best_results_static.json', 'r') as file:
    best_params_static = json.load(file)


best_params, results = k_fold_cross_validation_dynamic(
    StaticModelMultibranch,
    LSTMDynamicModel,
    data,
    CrossEntropyWithTemporalSmoothness,
    parameter_grid,
    best_params_static,
    dynamic_params["num_epochs"],
    dynamic_params["patience"],
    params["batch_size"],
    device,
    k_folds=3,
    seed=seed,
    cross_validation_on_loss=True,
    verbose=True
)

results_file = 'hyperparameters/cross_val_results_dynamic.json'
with open(results_file, 'w') as f:
    json.dump(results, f, indent=4)

best_file = 'hyperparameters/best_results_dynamic.json'
with open(best_file, 'w') as f:
    json.dump(best_params, f, indent=4)

# %% [markdown]
# ## Towards Intepretability: Modulable LSTM Model

# %% [markdown]
# Now that we have selected our best model, we try to interpret the results. Apart from correctly predicting protein locations, the main question of our problem is whether all different data are equally important for this task.
#
# Moving in this direction, we make the LSTM Module modulable: it can be trained on the whole dataset or only on part of it (in particular it can decide wheter to take __protein interactions matrix__, __protein concentration levels__ and __static_data__, with all the possible combinations available). As all other hyperparameters choice, refer to the `hyperparameters_cross_val.json` file.
#
# You can modify the three parameters there and afterwards run the following cells

# %%
# Define hyperparameters
with open('hyperparameters/hyperparameters_cross_val.json', 'r') as file:
    params = json.load(file)

dynamic_params = params["dynamic_model"]

# Set embedding dimensions based on json parameter
if static_params["long_embeddings"]:
    embedding_dim = 640
else:
    embedding_dim = 320

# %%
# Run training
train_loss, train_accuracy, test_loss, test_accuracy, model = dynamic_training(num_features, num_classes, num_timesteps, embedding_dim, dynamic_params, best_static_model, dataloader_train, dataloader_test, verbose, device)

# %% [markdown]
# Results of these multiple runs are given in detail on the report
